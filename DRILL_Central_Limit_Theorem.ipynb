# %%
import numpy as np
import pandas as pd
import scipy
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pop1 = np.random.binomial(10, .2, 10000)
pop2 = np.random.binomial(10, .5, 10000)

print('Population one mean is {} '.format(pop1.mean()))
print('Population one standard deviation is {} '.format(pop1.std()))
print('Population two mean is {} '.format(pop2.mean()))
print('Population two standard deviation is {} '.format(pop2.std()))

plt.hist(pop1, bins = range(0, 7), alpha=.5, label='Population 1')
plt.hist(pop2, alpha=.5, label='Population 2')
plt.legend(loc='upper right')

plt.axvline(pop1.mean(), color='b',linestyle='solid', linewidth=2)
plt.axvline(pop1.mean() + pop1.std(), color = 'b', linestyle='dashed', linewidth=2)
plt.axvline(pop1.mean() - pop1.std(), color='b', linestyle='dashed', linewidth=2)

plt.axvline(pop2.mean(), color='g',linestyle='solid', linewidth=2)
plt.axvline(pop2.mean() + pop2.std(), color = 'g', linestyle='dashed', linewidth=2)
plt.axvline(pop2.mean() - pop2.std(), color='g', linestyle='dashed', linewidth=2)

plt.show()

print(pop1)
# Out:
# Population one mean is 2.0119
# Population one standard deviation is 1.2726187135194893
# Population two mean is 4.9977
# Population two standard deviation is 1.5835070918691838
# [3 0 3 ... 1 2 3]

# %%
#Sample mean and standard deviation are relatively close to the population mean and std

sample1 = np.random.choice(pop1, 100, replace=True)
sample2 = np.random.choice(pop2, 100, replace=True)

diff=sample2.mean() - sample1.mean()

print('Sample one mean is {} '.format(sample1.mean()))
print('Sample one standard deviation is {} '.format(sample1.std()))
print('Sample two mean is {} '.format(sample2.mean()))
print('Sample two standard deviation is {} '.format(sample2.std()))
print('The difference between the two samples is {}'.format(diff))

plt.hist(sample1, bins = range(0, 15), alpha=.5, label='sample 1')
plt.axvline(sample1.mean(), color='b',linestyle='solid', linewidth=2)
plt.axvline(sample1.mean() + sample1.std(), color = 'b', linestyle='dashed', linewidth=2)
plt.axvline(sample1.mean() - sample1.std(), color='b', linestyle='dashed', linewidth=2)

plt.hist(sample2, bins = range(0, 15), alpha=.5, label = 'sample 2')
plt.axvline(sample2.mean(), color='g', linestyle='solid', linewidth=2)
plt.axvline(sample2.mean() + sample2.std(), color='g', linestyle='dashed', linewidth=2)
plt.axvline(sample2.mean() - sample2.std(), color='g', linestyle='dashed',linewidth=2)
plt.legend(loc='upper right')

plt.show()
# Out:
# Sample one mean is 1.82
# Sample one standard deviation is 1.2278436382536662
# Sample two mean is 4.9
# Sample two standard deviation is 1.493318452306808
# The difference between the two samples is 3.08

# %%
# With sample size of 1000, the mean and the standard deviation are very close the population mean and std. 
#The difference between the means of the two samples is smaller.

sample1_new = np.random.choice(pop1, 1000, replace=True)
sample2_new = np.random.choice(pop2, 1000, replace=True)

diff_new=sample2_new.mean() - sample1_new.mean()

print('Sample one mean is now {} '.format(sample1_new.mean()))
print('Sample one standard deviation is now {} '.format(sample1_new.std()))
print('Sample two mean is now {} '.format(sample2_new.mean()))
print('Sample two standard deviation is now {} '.format(sample2_new.std()))
print('The difference between the two samples is {}'.format(diff_new))

plt.hist(sample1_new,bins = range(0, 15), alpha=.5, label='sample 1_new')
plt.axvline(sample1_new.mean(), color='b',linestyle='solid', linewidth=2)
plt.axvline(sample1_new.mean() + sample1_new.std(), color = 'b', linestyle='dashed', linewidth=2)
plt.axvline(sample1_new.mean() - sample1_new.std(), color='b', linestyle='dashed', linewidth=2)

plt.hist(sample2_new, bins = range(0, 15), alpha=.5, label = 'sample 2_new')
plt.axvline(sample2_new.mean(), color='g', linestyle='solid', linewidth=2)
plt.axvline(sample2_new.mean() + sample2_new.std(), color='g', linestyle='dashed', linewidth=2)
plt.axvline(sample2_new.mean() - sample2_new.std(), color='g', linestyle='dashed',linewidth=2)
plt.legend(loc='upper right')

plt.show()
# Out:
# Sample one mean is now 2.042
# Sample one standard deviation is now 1.3169039448646207
# Sample two mean is now 4.946
# Sample two standard deviation is now 1.5482519174862985
# The difference between the two samples is 2.904

# %%
#With the sample size of 20, the mean and the standard deviation are not as close to the mean and std of the population 
# as they were with larger sample size.

sample1_small = np.random.choice(pop1, 20, replace=True)
sample2_small = np.random.choice(pop2, 20, replace=True)

diff_small=sample2_small.mean() - sample1_small.mean()


print('Sample one mean is now {} '.format(sample1_small.mean()))
print('Sample one standard deviation is now {} '.format(sample1_small.std()))
print('Sample two mean is now {} '.format(sample2_small.mean()))
print('Sample two standard deviation is now {} '.format(sample2_small.std()))
print('The difference between the two samples is {}'.format(diff_small))

plt.hist(sample1_small, bins = range(0, 10), alpha=.5, label='sample 1_small')
plt.axvline(sample1_small.mean(), color='b',linestyle='solid', linewidth=2)
plt.axvline(sample1_small.mean() + sample1_small.std(), color = 'b', linestyle='dashed', linewidth=2)
plt.axvline(sample1_small.mean() - sample1_small.std(), color='b', linestyle='dashed', linewidth=2)

plt.hist(sample2_small, bins = range(0, 15), alpha=.5, label = 'sample 2_small')
plt.axvline(sample2_small.mean(), color='g', linestyle='solid', linewidth=2)
plt.axvline(sample2_small.mean() + sample2_small.std(), color='g', linestyle='dashed', linewidth=2)
plt.axvline(sample2_small.mean() - sample2_small.std(), color='g', linestyle='dashed',linewidth=2)
plt.legend(loc='upper right')

plt.show()
# Out:
# Sample one mean is now 2.0
# Sample one standard deviation is now 0.9486832980505138
# Sample two mean is now 5.2
# Sample two standard deviation is now 1.4352700094407325
# The difference between the two samples is 3.2

# %%
#Increasing the p-value to .3 leads to the increase in the mean and std of population one as well as sample one.

pop1_newpv = np.random.binomial(10, .3, 10000)
pop2_newpv = np.random.binomial(10, .5, 10000)

diff_newpv = pop2_newpv.mean() - pop1_newpv.mean()

print('Population one new mean is {} '.format(pop1_newpv.mean()))
print('Population one standard deviation is {} '.format(pop1_newpv.std()))


sample1_newpv = np.random.choice(pop1_newpv, 100, replace=True)
sample2_newpv = np.random.choice(pop2_newpv, 100, replace=True)

print('Sample one mean is {} '.format(sample1_newpv.mean()))
print('Sample one standard deviation is {} '.format(sample1_newpv.std()))
print('Sample two mean is {} '.format(sample2_newpv.mean()))
print('Sample two standard deviation is {} '.format(sample2_newpv.std()))
print('The difference between the two samples is {}'.format(diff_newpv))
      
plt.hist(sample1_newpv, bins = range(0, 15), alpha=.5, label='sample 1')
plt.axvline(sample1_newpv.mean(), color='b',linestyle='solid', linewidth=2)
plt.axvline(sample1_newpv.mean() + sample1_newpv.std(), color = 'b', linestyle='dashed', linewidth=2)
plt.axvline(sample1_newpv.mean() - sample1_newpv.std(), color='b', linestyle='dashed', linewidth=2)

plt.hist(sample2, bins = range(0, 15), alpha=.5, label = 'sample 2')
plt.axvline(sample2_newpv.mean(), color='g', linestyle='solid', linewidth=2)
plt.axvline(sample2_newpv.mean() + sample2_newpv.std(), color='g', linestyle='dashed', linewidth=2)
plt.axvline(sample2_newpv.mean() - sample2_newpv.std(), color='g', linestyle='dashed',linewidth=2)
plt.legend(loc='upper right')

from scipy.stats import ttest_ind
print(ttest_ind(sample2_newpv, sample1_newpv, equal_var=False))
plt.show()
# Out:
# Population one new mean is 3.021
# Population one standard deviation is 1.4479499300735506
# Sample one mean is 2.95
# Sample one standard deviation is 1.5644487847162016
# Sample two mean is 4.96
# Sample two standard deviation is 1.6548111674750083
# The difference between the two samples is 1.9752
# Ttest_indResult(statistic=8.782164864940558, pvalue=7.704377511217673e-16)

# %%
#Increasing the p-value to .4, the mean and standard deviation of population one as well as sample one increases. 
#t-statistic decreases, p-value increasses

pop1_last = np.random.binomial(10, .4, 10000)
pop2_last = np.random.binomial(10, .5, 10000)

print('Population one new mean is {} '.format(pop1_last.mean()))
print('Population one standard deviation is {} '.format(pop1_last.std()))

sample1_last = np.random.choice(pop1_last, 100, replace=True)
sample2_last = np.random.choice(pop2_last, 100, replace=True)

print('Sample one mean is {} '.format(sample1_last.mean()))
print('Sample one standard deviation is {} '.format(sample1_last.std()))
print('Sample two mean is {} '.format(sample2_last.mean()))
print('Sample two standard deviation is {} '.format(sample2_last.std()))

plt.hist(sample1_last, bins = range(0, 15), alpha=.5, label='sample 1')
plt.axvline(sample1_last.mean(), color='b',linestyle='solid', linewidth=2)
plt.axvline(sample1_last.mean() + sample1_last.std(), color = 'b', linestyle='dashed', linewidth=2)
plt.axvline(sample1_last.mean() - sample1_last.std(), color='b', linestyle='dashed', linewidth=2)

plt.hist(sample2_last, bins = range(0, 15), alpha=.5, label = 'sample 2')
plt.axvline(sample2_last.mean(), color='g', linestyle='solid', linewidth=2)
plt.axvline(sample2_last.mean() + sample2_last.std(), color='g', linestyle='dashed', linewidth=2)
plt.axvline(sample2_last.mean() - sample2_last.std(), color='g', linestyle='dashed',linewidth=2)
plt.legend(loc='upper right')

from scipy.stats import ttest_ind
print(ttest_ind(sample2_last, sample1_last, equal_var=False))
plt.show()
# Out:
# Population one new mean is 3.9825
# Population one standard deviation is 1.550739742832433
# Sample one mean is 3.97
# Sample one standard deviation is 1.4384366513684224
# Sample two mean is 4.65
# Sample two standard deviation is 1.6147755261955143
# Ttest_indResult(statistic=3.128681810897358, pvalue=0.0020246393244040288)

# %%
pop1 = np.random.gamma(5, 1, 10000)
pop2 = np.random.gamma(7, 1, 10000)

print('Population one mean is {} '.format(pop1.mean()))
print('Population one standard deviation is {} '.format(pop1.std()))
print('Population two mean is {} '.format(pop2.mean()))
print('Population two standard deviation is {} '.format(pop2.std()))

plt.hist(pop1, alpha=.5, label='Population 1')
plt.hist(pop2, alpha=.5, label='Population 2')
plt.legend(loc='upper right')

plt.axvline(pop1.mean(), color='b',linestyle='solid', linewidth=2)
plt.axvline(pop1.mean() + sample1.std(), color = 'b', linestyle='dashed', linewidth=2)
plt.axvline(pop1.mean() - sample1.std(), color='b', linestyle='dashed', linewidth=2)

plt.axvline(pop2.mean(), color='g',linestyle='solid', linewidth=2)
plt.axvline(pop2.mean() + sample1.std(), color = 'g', linestyle='dashed', linewidth=2)
plt.axvline(pop2.mean() - sample1.std(), color='g', linestyle='dashed', linewidth=2)
plt.title('Gamma Distributions')
plt.show()
# Out:
# Population one mean is 5.008141999168664
# Population one standard deviation is 2.240954557140332
# Population two mean is 6.962987284044022
# Population two standard deviation is 2.6665168521339493

# %%
#The sample mean values are somewhat close to the true population mean and std. 

sample1 = np.random.choice(pop1, 100, replace=True)
sample2 = np.random.choice(pop2, 100, replace=True)

print('Sample one mean is {} '.format(sample1.mean()))
print('Sample one standard deviation is {} '.format(sample1.std()))
print('Sample two mean is {} '.format(sample2.mean()))
print('Sample two standard deviation is {} '.format(sample2.std()))

plt.hist(sample1, alpha=.5, label='sample 1')
plt.axvline(sample1.mean(), color='b',linestyle='solid', linewidth=2)
plt.axvline(sample1.mean() + sample1.std(), color = 'b', linestyle='dashed', linewidth=2)
plt.axvline(sample1.mean() - sample1.std(), color='b', linestyle='dashed', linewidth=2)

plt.hist(sample2, bins = range(0, 18), alpha=.5, label = 'sample 2')
plt.axvline(sample2.mean(), color='g', linestyle='solid', linewidth=2)
plt.axvline(sample2.mean() + sample2.std(), color='g', linestyle='dashed', linewidth=2)
plt.axvline(sample2.mean() - sample2.std(), color='g', linestyle='dashed',linewidth=2)
plt.legend(loc='upper right')

plt.show()
# Out:
# Sample one mean is 5.683877926058951
# Sample one standard deviation is 2.323832269581752
# Sample two mean is 6.835729636998585
# Sample two standard deviation is 2.44183326474983
