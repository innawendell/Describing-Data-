# %%
import pandas as pd

# %%
pubs = pd.read_csv('C:\Inna\'s files\data\Pubs\pubs.csv')
#print(pubs)
pubs.groupby('Stratum').describe()
# Out:
#           Age                                                      Income  \
#          count       mean        std   min   25%   50%   75%   max  count
# Stratum
# Capital  139.0  19.604317   2.518392  16.0  18.0  19.0  20.0  41.0  138.0
# Rural      3.0  25.333333  11.846237  18.0  18.5  19.0  29.0  39.0    3.0
# Urban     33.0  18.787879   1.363763  16.0  18.0  19.0  20.0  21.0   33.0
#
#                          ...                            WTS               \
#                   mean   ...          75%        max  count         mean
# Stratum                  ...
# Capital  118227.536232   ...     100000.0  4500000.0  136.0  4886.029412
# Rural    164666.666667   ...     222000.0   384000.0    3.0  7000.000000
# Urban     71666.666667   ...     100000.0   270000.0   33.0  4409.090909
#
#
#                  std     min     25%     50%     75%      max
# Stratum
# Capital  4466.321260     0.0  2000.0  4000.0  5000.0  30000.0
# ...

# %%
pubs.groupby('Gender').describe()
# Out:
#          Age                                                     Income  \
#         count       mean       std   min   25%   50%   75%   max  count
# Gender
# Female  102.0  19.411765  2.633948  16.0  18.0  19.0  20.0  41.0  102.0
# Male     73.0  19.739726  2.958169  16.0  18.0  19.0  20.0  39.0   72.0
#
#                         ...                            WTS               \
#                  mean   ...          75%        max  count         mean
# Gender                  ...
# Female   63435.294118   ...      80000.0   700000.0  100.0  4030.000000
# Male    176444.444444   ...     150000.0  4500000.0   72.0  5944.444444
#
#
#                 std  min     25%     50%     75%      max
# Gender
# Female  3678.232448  0.0  2000.0  3000.0  5000.0  30000.0
# Male    4899.378773  0.0  3000.0  5000.0  7000.0  25000.0
#
# [2 rows x 24 columns]

# %%
pubs.groupby('Occupation').describe()
# Out:
#                                    Age                                    \
#                                   count       mean       std   min   25%
# Occupation
# CEO                                 1.0  16.000000       NaN  16.0  16.0
# Entrepreneur / Software Engineer    1.0  22.000000       NaN  22.0  22.0
# Student                           122.0  18.852459  1.168966  16.0  18.0
# Student + working                  40.0  19.950000  1.431334  18.0  19.0
# Working                             9.0  26.666667  7.968689  19.0  23.0
# Working                             1.0  26.000000       NaN  26.0  26.0
# army                                1.0  19.000000       NaN  19.0  19.0
#
#                                                    Income                \
#                                    50%   75%   max  count          mean
# Occupation
# CEO                               16.0  16.0  16.0    1.0  2.000000e+05
# ...
